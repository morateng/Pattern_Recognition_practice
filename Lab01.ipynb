# %%
import os
import cv2
import matplotlib.pyplot as plt

from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/패턴인식/PR201910769/images/lab01_rainbow.jpg') # path

# %%
cv2_imshow(img)

# %%
img.shape

# %%
img = cv2.resize(img, (500, 400))

# %%
cv2_imshow(img)

# %%
img

# %%
cv2_imshow(img[:100,:,:])

# %%
cv2_imshow(img[:,:,0])

# %%
cv2_imshow(img[:,:,1])

# %%
cv2_imshow(img[:,:,2])

# %%
bimg = img.copy()
bimg[:,:,1] = 0
bimg[:,:,2] = 0

cv2_imshow(bimg)

# %%
imggray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cv2_imshow(imggray)

# %%
imggray.shape

# %%
imggray.flatten().shape

# %%
plt.hist(imggray.flatten(), bins=255)

# %%
grayhist = cv2.calcHist([imggray], [0], None, [256], [0,256])
print(grayhist.shape)
plt.plot(grayhist)

# %%
plt.hist(img[:,:,0].flatten(), bins=256)

# %%
plt.hist(img[:,:,1].flatten(), bins=256)

# %%
plt.hist(img[:,:,2].flatten(), bins=256)
